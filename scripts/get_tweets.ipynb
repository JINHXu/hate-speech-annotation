# %% [markdown]
# # Get old tweets using the academic research endpoint through Twitter's API
#
# Get large trunck of tweets through Twitter's API: all \#china tweets posted during the year of 2020 and 2021 quarter by quarter (excl. retweets/quotes/reply).
#
# _Author: Jinghua Xu_
#
# _reference: [https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a](https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a)_
#
# _[Twitter developer portal](https://developer.twitter.com/en/portal/dashboard)_

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAIE%2BZgEAAAAAf5nHOqUwHaylmZeOihu%2FIqfrsL8%3DEKzW6lM4XxrzGEW3kvS5AL5l0esZvTX6fC5ACEW9Y85xRZ2jDD'

# %%
def auth():
    return os.getenv('TOKEN')

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': 500,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "#china lang:en -is:retweet -is:reply -is:quote"
start_time = "2019-01-01T00:00:00.000Z"
end_time = "2020-01-01T00:00:00.000Z"

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # # 3. Geolocation
        # if ('geo' in tweet):   
        #     if 'place_id' in tweet['geo']:
        #       geo = tweet['geo']['place_id']
        #     else:
        #       geo = " "
        # else:
        #     geo = " "

        # 4. Tweet ID
        tweet_id = tweet['id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        # source = tweet['source']

        if 'source' in tweet.keys():
          source = tweet['source']
        else:
          source = 'unk'

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [author_id, created_at, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
#Total number of tweets we collected from the loop
total_tweets = 0

# output file name
fn = "2019.csv"

# fn = '2022_last_day.csv'

# Create file
csvFile = open(fn, "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

# Inputs
count = 0 # Counting tweets per time period
# max_count = 100 # Max tweets per time period
flag = True
next_token = None
max_results = 500

# Check if flag is true
while flag:
    print("-------------------")
    print("Token: ", next_token)
    url = create_url(keyword, start_time,end_time)
    json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
    result_count = json_response['meta']['result_count']

    if 'next_token' in json_response['meta']:
        # Save the token to use for next call
        next_token = json_response['meta']['next_token']
        print("Next Token: ", next_token)
        if result_count is not None and result_count > 0 and next_token is not None:
            print("Start Date: ", start_time)
            append_to_csv(json_response, fn)
            count += result_count
            total_tweets += result_count
            print("Total # of Tweets added: ", total_tweets)
            print("-------------------")
            time.sleep(5)                
    # If no next token exists
    else:
        if result_count is not None and result_count > 0:
            print("-------------------")
            print("Start Date: ", start_time)
            append_to_csv(json_response, fn)
            count += result_count
            total_tweets += result_count
            print("Total # of Tweets added: ", total_tweets)
            print("-------------------")
            time.sleep(5)
        
        #Since this is the final request, turn flag to false to move to the next time period.
        flag = False
        next_token = None
    time.sleep(5)
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yevg082xkgb2tunix9exhh23ukd
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  477
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yevg082xkgb2tunix9exhh23ukd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegtlf79eokg0lfdaxdnylxh08t
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  963
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegtlf79eokg0lfdaxdnylxh08t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegrhadoogry2oepuvnzo87ohvh
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  1440
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegrhadoogry2oepuvnzo87ohvh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegpck6uiqez4cqizta43bpeef1
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  480
# Total # of Tweets added:  1920
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegpck6uiqez4cqizta43bpeef1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegn7u639y8r1790x6kolb0ruyl
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  2406
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegn7u639y8r1790x6kolb0ruyl
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegn5qijcx4fsvdmrxh51t4qef1
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  478
# Total # of Tweets added:  2884
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegn5qijcx4fsvdmrxh51t4qef1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegl1wqh3or0tn39wy2f07o89kt
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  484
# Total # of Tweets added:  3368
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegl1wqh3or0tn39wy2f07o89kt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegivzq1cpt25yjlav3l845rqm5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  3845
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegivzq1cpt25yjlav3l845rqm5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegeoxhqel010llpz27bdspl18d
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  484
# Total # of Tweets added:  4329
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegeoxhqel010llpz27bdspl18d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegcjlw2a5d0erwwgyuferkf1q5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  479
# Total # of Tweets added:  4808
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegcjlw2a5d0erwwgyuferkf1q5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yegaddmiybc0w1kczy0oaiakqyl
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  5285
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6yegaddmiybc0w1kczy0oaiakqyl
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye1nxz6097f3jlm1o2or7dpp94t
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  5762
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye1nxz6097f3jlm1o2or7dpp94t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye1lt8xnhbx4p32axv8l16gb799
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  485
# Total # of Tweets added:  6247
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye1lt8xnhbx4p32axv8l16gb799
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye1hllglh9lr7bbk1mhorjwqzct
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  488
# Total # of Tweets added:  6735
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye1hllglh9lr7bbk1mhorjwqzct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye1fh5z5g8f7hst0c7nhxbfzpfh
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  7212
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye1fh5z5g8f7hst0c7nhxbfzpfh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye1ferqr28lsjry2uqz62c3coe5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  484
# Total # of Tweets added:  7696
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye1ferqr28lsjry2uqz62c3coe5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye1da1t12dbwiddcxzc2g36uwl9
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  473
# Total # of Tweets added:  8169
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye1da1t12dbwiddcxzc2g36uwl9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye192ov9mrtqqvh6n1b8lpq95rx
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  475
# Total # of Tweets added:  8644
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye192ov9mrtqqvh6n1b8lpq95rx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye16y9mwx5dh1lr4yxr3wwrl0u5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  488
# Total # of Tweets added:  9132
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye16y9mwx5dh1lr4yxr3wwrl0u5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6ye16vvbgukrpydgl2hzcmow8vb1
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  491
# Total # of Tweets added:  9623
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6ye16vvbgukrpydgl2hzcmow8vb1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi26g25ekmin4bfpyg502h5mjct
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  487
# Total # of Tweets added:  10110
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi26g25ekmin4bfpyg502h5mjct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi24a4ms00tdzkgem6w1nfcoepp
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  480
# Total # of Tweets added:  10590
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi24a4ms00tdzkgem6w1nfcoepp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi224t77nbp5sm4t3krtkoytev1
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  11076
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi224t77nbp5sm4t3krtkoytev1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1xwk285k4tymyh3nhemcxqk59
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  485
# Total # of Tweets added:  11561
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1xwk285k4tymyh3nhemcxqk59
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1vsf8ms4aw7c5wz8tvkn83fct
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  488
# Total # of Tweets added:  12049
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1vsf8ms4aw7c5wz8tvkn83fct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1toal446u3wy3pt7f59calnct
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  482
# Total # of Tweets added:  12531
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1toal446u3wy3pt7f59calnct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1tllhadoxy98wsrqlr6nh0wvx
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  484
# Total # of Tweets added:  13015
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1tllhadoxy98wsrqlr6nh0wvx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1pejsntab2o0r6sv4o0vu22d9
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  485
# Total # of Tweets added:  13500
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1pejsntab2o0r6sv4o0vu22d9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1pcg9nreho5hz58zrynbxg3ul
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  479
# Total # of Tweets added:  13979
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1pcg9nreho5hz58zrynbxg3ul
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1n97wf90bqfwsblw8pywltoxp
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  483
# Total # of Tweets added:  14462
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1n97wf90bqfwsblw8pywltoxp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vi1n7fexvxsochnvat36sodogvx
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  14948
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vi1n7fexvxsochnvat36sodogvx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhn0tt9uhwx6nhv97c1vpyol3zx
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  494
# Total # of Tweets added:  15442
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhn0tt9uhwx6nhv97c1vpyol3zx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhn0s0hrmanchg9z1amy3mni83h
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  491
# Total # of Tweets added:  15933
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhn0s0hrmanchg9z1amy3mni83h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmwkyt4mqi54f8iefpsmrncr5p
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  474
# Total # of Tweets added:  16407
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmwkyt4mqi54f8iefpsmrncr5p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmwiv2j99ctmptk3kdv4v2qsu5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  480
# Total # of Tweets added:  16887
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmwiv2j99ctmptk3kdv4v2qsu5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmudu7sqgco09yo188q9tbrkvx
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  484
# Total # of Tweets added:  17371
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmudu7sqgco09yo188q9tbrkvx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmq66trri4129iajv42jrt9shp
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  485
# Total # of Tweets added:  17856
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmq66trri4129iajv42jrt9shp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmo2co2yujqa54ivkbb49w0fi5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  480
# Total # of Tweets added:  18336
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmo2co2yujqa54ivkbb49w0fi5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmnznos14dcijbo5znbso1yoot
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  482
# Total # of Tweets added:  18818
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmnznos14dcijbo5znbso1yoot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmjs04pfc5plkosykhzxvm2dtp
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  487
# Total # of Tweets added:  19305
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmjs04pfc5plkosykhzxvm2dtp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmhnktbvzduq4b86lwnjw2q0sd
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  19782
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmhnktbvzduq4b86lwnjw2q0sd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhmhlhdc8eohn2r3cmbtmm99ke5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  481
# Total # of Tweets added:  20263
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vhmhlhdc8eohn2r3cmbtmm99ke5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7v6za3vjx2eqvdbr8avyaq8ot
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  483
# Total # of Tweets added:  20746
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7v6za3vjx2eqvdbr8avyaq8ot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7t2jr5nbk8mpazqortltmed19
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  492
# Total # of Tweets added:  21238
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7t2jr5nbk8mpazqortltmed19
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7qxirummhrnc6m8b7vcdbhh8d
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  485
# Total # of Tweets added:  21723
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7qxirummhrnc6m8b7vcdbhh8d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7otp7dwkpnr4qvgygazdjed19
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  480
# Total # of Tweets added:  22203
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7otp7dwkpnr4qvgygazdjed19
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7orw7qzbyvyubh77l9c7w52m5
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  484
# Total # of Tweets added:  22687
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7orw7qzbyvyubh77l9c7w52m5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7mo2e6y673bx6xrzta9cdd1ml
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  488
# Total # of Tweets added:  23175
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7mo2e6y673bx6xrzta9cdd1ml
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7kj1hx66gwh0r21giyffumw71
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  492
# Total # of Tweets added:  23667
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7kj1hx66gwh0r21giyffumw71
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7iex20gy1mnh9bz48drfvo48t
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  478
# Total # of Tweets added:  24145
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7iex20gy1mnh9bz48drfvo48t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vh7gbe2cik6qmxwim7aivjzkh31
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  483
# Total # of Tweets added:  24628
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fo6vh7gbe2cik6qmxwim7aivjzkh31
# Endpoint Response Code: 503
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-18-82f324221dbb> in <cell line: 25>()
#      27     print("Token: ", next_token)
#      28     url = create_url(keyword, start_time,end_time)
# ---> 29     json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
#      30     result_count = json_response['meta']['result_count']
#      31
#
# <ipython-input-15-aa4529738a63> in connect_to_endpoint(url, headers, params, next_token)
#       4     print("Endpoint Response Code: " + str(response.status_code))
#       5     if response.status_code != 200:
# ----> 6         raise Exception(response.status_code, response.text)
#       7     return response.json()
#
# Exception: (503, '{"title":"Service Unavailable","detail":"Service Unavailable","type":"about:blank","status":503}')

# %% [markdown]
# ## Data Overview

# %%
df = pd.read_csv(fn)
df
# Out:
#                  author id                 created_at                   id  \
# 0               3246529033  2019-12-31 23:59:58+00:00  1212161506277646336
# 1      1116168151048146944  2019-12-31 23:59:36+00:00  1212161412048605191
# 2       973925072841867264  2019-12-31 23:59:29+00:00  1212161385729269760
# 3                 29097819  2019-12-31 23:55:02+00:00  1212160265535528961
# 4       968210551582199808  2019-12-31 23:53:35+00:00  1212159897619423232
# ...                    ...                        ...                  ...
# 24623             58836985  2019-12-18 13:09:47+00:00  1207286839708663808
# 24624  1041452573323157504  2019-12-18 13:09:38+00:00  1207286800177410050
# 24625   917672895987552259  2019-12-18 13:07:19+00:00  1207286216699338752
# 24626   960129987998244865  2019-12-18 13:07:01+00:00  1207286142288068609
# 24627           1026953454  2019-12-18 13:06:43+00:00  1207286066820063232
#
#       lang  like_count  quote_count  reply_count  retweet_count source  \
# 0       en           0            0            0              0    unk
# 1       en           0            0            0              0    unk
# 2       en           3            0            0              0    unk
# 3       en          52           12            8             72    unk
# 4       en           0            0            0              0    unk
# ...    ...         ...          ...          ...            ...    ...
# 24623   en           0            0            0              0    unk
# 24624   en           0            0            0              0    unk
# 24625   en           0            0            1              1    unk
# 24626   en           0            0            0              0    unk
# 24627   en           1            0            0              0    unk
#
#                                                    tweet
# 0      With #islamist terrorists one of our biggest t...
# 1      A member of the Early Rain Church in #China fa...
# 2      h a p p i n e s s 🕊\n.\n.\n.\n#China @china ht...
# 3      A shadowy new alliance led by pro-#China #Comm...
# 4      .@PayPal completes #GoPay acquisition, allowin...
# ...                                                  ...
# 24623  The latest The Plass Appliance Home Daily! htt...
# 24624  Chinese Crypto Fitness App Reportedly Under In...
# 24625  🇨🇳 #ChinaTrends #4: our fourth quarterly publi...
# 24626  World markets were lifted in the first two day...
# 24627  For sale:\n\nhttps://t.co/wVFmSGhERq\n\n#domai...
#
# [24628 rows x 10 columns]

# %%
len(df)

# %%
# from google.colab import files
# files.download(fn)

# %%
# # connect to drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# # save to g drive
# !cp -r '/content/2022_Q4.csv' '/content/drive/MyDrive/#CHINA HATE'

# %%
# # save to g drive
# ! cp -r '/content/2019.csv' '/content/drive/MyDrive/CHINA_HATE'
